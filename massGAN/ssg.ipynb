# %%
import utils

utils.mesh2binvox(path="./data/mvrdv/mvrdv.obj", resolution=32, normalize=True, overwrite=True)

# %%
import binvox_rw
import utils

path = './data/mvrdv/mvrdv_norm.binvox'
with open(path, 'rb') as f:
    model = binvox_rw.read_as_3d_array(f)
    utils.plot_binvox(data=model.data, plot_voxels=True, map_y_to_z=True)
